# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("data/zipfel_zapf.csv")
df_density = pd.read_excel('../density.xlsx')
df_post = pd.read_csv('../post-codes.csv')

# %%
# Salary Overview
salary_dict = {}
for s in df['Salary']:
    if s in salary_dict:
        salary_dict[s] += 1
    else:
        salary_dict[s] = 1
print(salary_dict)
# Out:
# {'Marktüblich': 45, '20-25 CHF': 10, '25-30 CHF': 3, '30-35 CHF': 4}

# %%
import numpy as np
import matplotlib.pyplot as plt
names = list(salary_dict.keys())
values = list(salary_dict.values())

plt.bar(range(len(salary_dict)), values, tick_label=names)
plt.show()

# %%
# Frequency Overview
freq_dict = {}
for f in df['Freq']:
    if f in freq_dict:
        freq_dict[f] += 1
    else:
        freq_dict[f] = 1
print(freq_dict)
# Out:
# {'Regelmässig': 51, 'Einmalig': 2, 'Mehrmalig': 9}

# %%
def city(row):
    l = row['Location'].split()
    return l[0]
        
df['City'] = df.apply(city, axis=1)

df = df.merge(df_post.drop_duplicates(['post_district']), right_on = 'post_district', left_on = 'City', how = 'inner')
df
# Out:
#           Date                               Position         Freq  \
# 0   15.10.2023                                  Nanny  Regelmässig
# 1   06.10.2023                                  Nanny  Regelmässig
# 2   06.10.2023                                  Nanny  Regelmässig
# 3   25.09.2023                                  Nanny  Regelmässig
# 4   14.09.2023                                  Nanny  Regelmässig
# 5   09.09.2023                  Babysitter oder Nanny  Regelmässig
# 6   07.09.2023                                  Nanny  Regelmässig
# 7   24.08.2023                          Nanny vor Ort  Regelmässig
# 8   22.08.2023                        Kinderbetreuung  Regelmässig
# 9   17.08.2023                                  Nanny     Einmalig
# 10  10.08.2023                            Tagesmutter    Mehrmalig
# 11  05.08.2023                                  Nanny  Regelmässig
# 12  12.07.2023                                  Nanny  Regelmässig
# 13  30.06.2023                             Babysitter    Mehrmalig
# 14  09.06.2023                                  Nanny  Regelmässig
# 15  25.06.2023                         Tagesbetreuung  Regelmässig
# 16  24.06.2023                                  Nanny  Regelmässig
# 17  13.06.2023  Gute Seele für Haus, Baby und Familie  Regelmässig
# 18  06.06.2023                                  Nanny  Regelmässig
# 19  01.05.2023                      Tagesmutter/Nanny  Regelmässig
# 20  29.04.2023                                  Nanny  Regelmässig
# 21  24.04.2023                                  Nanny  Regelmässig
# 22  23.04.2023                                  Nanny  Regelmässig
# 23  12.04.2023                                  Nanny  Regelmässig
# 24  07.04.2023                                  Nanny  Regelmässig
# 25  07.03.2023                             Kinderfrau    Mehrmalig
# 26  03.11.2022                            Tagesmutter    Mehrmalig
# 27  25.02.2023                Nanny / Kinderbetreuung  Regelmässig
# 28  17.02.2023                                  Nanny  Regelmässig
# 29  04.01.2023                                  Nanny  Regelmässig
# 30  21.12.2022                                  Nanny  Regelmässig
# 31  18.12.2022                                  Nanny  Regelmässig
# 32  06.11.2022                                  Nanny  Regelmässig
# 33  10.10.2022           Tagesmutter + Haushaltshilfe  Regelmässig
# 34  07.10.2022                                  Nanny  Regelmässig
# 35  23.09.2022                                  Nanny  Regelmässig
# 36  16.08.2022                Kinderbetreuung vor Ort  Regelmässig
# 37  15.08.2022                             Babysitter  Regelmässig
# 38  02.08.2022                             Babysitter    Mehrmalig
# 39  14.07.2022                                  Nanny  Regelmässig
# 40  06.07.2022                                  Nanny  Regelmässig
# 41  14.03.2022                                  Nanny    Mehrmalig
# 42  08.07.2022                           Babysitterin  Regelmässig
# 43  31.03.2022                       Nanny/ Tagesmami  Regelmässig
# 44  31.03.2022                       Nanny/ Tagesmami  Regelmässig
#
#          Salary                              StartDate  \
# 0   Marktüblich                      Februar/März 2024
# 1     25-30 CHF                                 sofort
# 2   Marktüblich                                    NaN
# 3   Marktüblich                             01.01.2024
# 4   Marktüblich                         Nach Absprache
# 5   Marktüblich                    So bald als möglich
# 6     20-25 CHF                             01.01.2024
# 7     25-30 CHF                01.11.2023 - 31.01.2024
# 8     20-25 CHF                                    NaN
# 9   Marktüblich                                    NaN
# 10    20-25 CHF                                   28.8
# 11    20-25 CHF                                 Sofort
# 12  Marktüblich                              Herbst 23
# 13  Marktüblich                                    NaN
# 14    20-25 CHF                     Mid-September 2023
# 15  Marktüblich                      nach Vereinbarung
# 16  Marktüblich                                 1.7.23
# 17    20-25 CHF                 Mitte Juli/August 2023
# 18  Marktüblich                            August 2023
# 19  Marktüblich                             Mitte Juni
# 20  Marktüblich                                 Sofort
# 21    20-25 CHF                                    NaN
# 22  Marktüblich  Ab sofort oder so schnell wie möglich
# 23  Marktüblich                    1. Mai oder 1. Juni
# 24    30-35 CHF                      Nach Vereinbarung
# 25  Marktüblich                              ab sofort
# 26    20-25 CHF                 So schnell wie möglich
# 27  Marktüblich                                 Mai 23
# 28    20-25 CHF                                    NaN
# 29    30-35 CHF                             01.06.2023
# 30  Marktüblich                         Nach Absprache
# 31  Marktüblich                              Ab sofort
# 32  Marktüblich                               Dezember
# 33  Marktüblich                            Januar 2023
# 34  Marktüblich                             01.04.2023
# 35  Marktüblich                       18. Oktober 2022
# 36  Marktüblich                              Ab sofort
# 37  Marktüblich                                    NaN
# 38  Marktüblich                                    NaN
# 39  Marktüblich                                 August
# 40  Marktüblich          August oder nach Vereinbarung
# 41  Marktüblich                       Ab April möglich
# 42    30-35 CHF                                22.8.22
# 43  Marktüblich                                 Sofort
# 44  Marktüblich                                 Sofort
#
#                              Location  \
# 0                      Aarau - Aargau
# 1         Schaffhausen - Schaffhausen
# 2                         Flawil (SG)
# 3             Stüsslingen - Solothurn
# 4                    Rombach - Aargau
# 5                   Jona - St. Gallen
# 6                    Hallwil - Aargau
# 7                     Kloten - Zürich
# 8                 Winterthur - Zürich
# 9               Brüttisellen - Zürich
# 10                    Schwyz - Schwyz
# 11                 Amden - St. Gallen
# 12                      Sins - Aargau
# 13                Rüschlikon - Zürich
# 14                Rüschlikon - Zürich
# 15               Weisslingen - Zürich
# 16                 Kollbrunn - Zürich
# 17                       Altendorf SZ
# 18                   Staufen - Aargau
# 19             Uerschhausen - Thurgau
# 20  Speicher - Appenzell Ausserrhoden
# 21                Wallenwil - Thurgau
# 22            Untereggen - St. Gallen
# 23                 Wädenswil - Zürich
# 24                 Uzwil - St. Gallen
# 25                    Arbon - Thurgau
# 26                    Arbon - Thurgau
# 27                  Galgenen - Schwyz
# 28               Lipperswil - Thurgau
# 29               Ermatingen - Thurgau
# 30               Richterswil - Zürich
# 31                  Wildberg - Zürich
# 32               Oberdiessbach - Bern
# 33                   Märwil - Thurgau
# 34                   Zumikon - Zürich
# 35               Weinfelden - Thurgau
# 36               Bettlach - Solothurn
# 37                    Zürich - Zürich
# 38                    Zürich - Zürich
# 39                    Zürich - Zürich
# 40                    Zürich - Zürich
# 41                    Zürich - Zürich
# 42                   Thalwil - Zürich
# 43    Berneck - Appenzell Innerrhoden
# 44               Berneck - St. Gallen
#
#                                                  Days           City  \
# 0                              1 Tag à ca 8-9 Stunden          Aarau
# 1                  Donnerstag, ~9 Stunden ab 7.45 Uhr   Schaffhausen
# 2                                        1 bis 2 Tage         Flawil
# 3                              Mo, Mi, Do, Fr; 8h/Tag    Stüsslingen
# 4                                   Dienstag 7-18 Uhr        Rombach
# 5   4-6 Stunden an einem Tag (Freitag) optional Mi...           Jona
# 6                Di bis Fr oder Mo bis Do, 34 Stunden        Hallwil
# 7                                3 Tage a 3-4 Stunden         Kloten
# 8                                0.5-2.5 Tage / Woche     Winterthur
# 9                                               1 Tag   Brüttisellen
# 10                               Div. Wochentage 4-7h         Schwyz
# 11                             5 Tage zu je 2 Stunden          Amden
# 12                                         1 Tag (8h)           Sins
# 13                            Flexibel nach Absprache     Rüschlikon
# 14                        3 Tage wählbar, je 9-17/18h     Rüschlikon
# 15                                          8h /Woche    Weisslingen
# 16                                      3 Tage a 4 St      Kollbrunn
# 17                               2.5-3.5 Tage / 20-28      Altendorf
# 18                                      ca. 24h/Woche        Staufen
# 19         2Tg. wählbar aus Mi/ Do/ Fr - je 11-17/18H   Uerschhausen
# 20  Stundenweise bis halber Tag pro Woche (Mo, Di ...       Speicher
# 21                                  Nach Vereinbarung      Wallenwil
# 22                                    Mi & Fr, 07-18H     Untereggen
# 23                            18-22 Stunden, 2-3 Tage      Wädenswil
# 24                      2 Halbtage (je ca. 6 Stunden)          Uzwil
# 25                                    1Tag/ 4 Stunden          Arbon
# 26       1-2 mal in der woche für höchstens 9 stunden          Arbon
# 27                              3-4 Tage / variierend       Galgenen
# 28       18-36h Samstag, Sonntag, Montag und Dienstag     Lipperswil
# 29                                   1-2 Tage / Woche     Ermatingen
# 30                      1/2 tag + zusätzliche stunden    Richterswil
# 31                                  Montag Nachmittag       Wildberg
# 32          Montag morgen /Dienstag morgen jeweils 4h  Oberdiessbach
# 33                                                70%         Märwil
# 34                                             2 Tage        Zumikon
# 35                   3-4h jeweils Dienstag Nachmittag     Weinfelden
# 36                    2 Tage frei wählbar/ 20 Stunden       Bettlach
# 37                        2 afternoons per week, 2-3h         Zürich
# 38                                         10 Stunden         Zürich
# 39                         2 - 3 halbe Tage pro Woche         Zürich
# 40                             Mittwoch 07:30 - 19:30         Zürich
# 41                                    8-16h pro Woche         Zürich
# 42                           Freitag, 17.30-22.30 Uhr        Thalwil
# 43                              3 Tage à 4-10 Stunden        Berneck
# 44                              3 Tage à 4-10 Stunden        Berneck
#
#     Post Code  post_district comment country_code region           town  \
# 0        5000          Aarau     NaN           CH     AG          Aarau
# 1        8200   Schaffhausen     NaN           CH     SH   Schaffhausen
# 2        9230         Flawil     NaN           CH     SG         Flawil
# 3        4655    Stüsslingen     NaN           CH     SO    Stüsslingen
# 4        5022        Rombach     NaN           CH     AG        Rombach
# 5        8645           Jona     NaN           CH     SG           Jona
# 6        5705        Hallwil     NaN           CH     AG        Hallwil
# 7        8302         Kloten     NaN           CH     ZH         Kloten
# 8        8400     Winterthur     NaN           CH     ZH     Winterthur
# 9        8306   Brüttisellen     NaN           CH     ZH   Brüttisellen
# 10       6430         Schwyz     NaN           CH     SZ         Schwyz
# 11       8873          Amden     NaN           CH     SG          Amden
# 12       5643           Sins     NaN           CH     AG           Sins
# 13       8803     Rüschlikon     NaN           CH     ZH     Rüschlikon
# 14       8803     Rüschlikon     NaN           CH     ZH     Rüschlikon
# 15       8484    Weisslingen     NaN           CH     ZH    Weisslingen
# 16       8483      Kollbrunn     NaN           CH     ZH      Kollbrunn
# 17       8852      Altendorf     NaN           CH     SZ      Altendorf
# 18       5603        Staufen     NaN           CH     AG        Staufen
# 19       8537   Uerschhausen     NaN           CH     TG   Uerschhausen
# 20       9042       Speicher     NaN           CH     AR       Speicher
# 21       8360      Wallenwil     NaN           CH     TG      Wallenwil
# 22       9033     Untereggen     NaN           CH     SG     Untereggen
# 23       8820      Wädenswil     NaN           CH     ZH      Wädenswil
# 24       9240          Uzwil     NaN           CH     SG          Uzwil
# 25       9320          Arbon     NaN           CH     TG          Arbon
# 26       9320          Arbon     NaN           CH     TG          Arbon
# 27       8854       Galgenen     NaN           CH     SZ       Galgenen
# 28       8564     Lipperswil     NaN           CH     TG     Lipperswil
# 29       8272     Ermatingen     NaN           CH     TG     Ermatingen
# 30       8805    Richterswil     NaN           CH     ZH    Richterswil
# 31       8489       Wildberg     NaN           CH     ZH       Wildberg
# 32       3672  Oberdiessbach     NaN           CH     BE  Oberdiessbach
# 33       9562         Märwil     NaN           CH     TG         Märwil
# 34       8126        Zumikon     NaN           CH     ZH        Zumikon
# 35       8570     Weinfelden     NaN           CH     TG     Weinfelden
# 36       2544       Bettlach     NaN           CH     SO       Bettlach
# 37       8000         Zürich     NaN           CH     ZH         Zürich
# 38       8000         Zürich     NaN           CH     ZH         Zürich
# 39       8000         Zürich     NaN           CH     ZH         Zürich
# 40       8000         Zürich     NaN           CH     ZH         Zürich
# 41       8000         Zürich     NaN           CH     ZH         Zürich
# 42       8800        Thalwil     NaN           CH     ZH        Thalwil
# 43       9442        Berneck     NaN           CH     SG        Berneck
# 44       9442        Berneck     NaN           CH     SG        Berneck
#
#           lat       lng
# 0   47.387958  8.044136
# 1   47.711418  8.626545
# 2   47.413371  9.187030
# 3   47.393752  7.970652
# 4   47.403250  8.047435
# 5   47.230190  8.845540
# 6   47.329966  8.174391
# 7   47.449512  8.582165
# 8   47.485687  8.729292
# 9   47.423190  8.629710
# 10  47.032645  8.669276
# 11  47.169767  9.174440
# 12  47.199099  8.378360
# 13  47.308322  8.554446
# 14  47.308322  8.554446
# 15  47.431923  8.763459
# 16  47.455699  8.765970
# 17  47.176924  8.835010
# 18  47.383689  8.168198
# 19  47.608454  8.817285
# 20  47.408970  9.444043
# 21  47.457651  8.955700
# 22  47.452986  9.449917
# 23  47.225553  8.649509
# 24  47.430379  9.151270
# 25  47.514091  9.426830
# 26  47.514091  9.426830
# 27  47.180683  8.875679
# 28  47.616849  9.078491
# 29  47.655539  9.090917
# 30  47.209707  8.696260
# 31  47.419509  8.819044
# 32  46.839663  7.618735
# 33  47.531784  9.073673
# 34  47.329895  8.623969
# 35  47.566030  9.108446
# 36  47.202684  7.424107
# 37  47.381813  8.535326
# 38  47.381813  8.535326
# 39  47.381813  8.535326
# 40  47.381813  8.535326
# 41  47.381813  8.535326
# 42  47.291326  8.560220
# 43  47.425506  9.613517
# 44  47.425506  9.613517

# %%
# Data group by post code
df_count = df.groupby(['Post Code']).size().reset_index(name = 'Counts')
df_count
# Out:
#     Post Code  Counts
# 0        2544       1
# 1        3672       1
# 2        4655       1
# 3        5000       1
# 4        5022       1
# 5        5603       1
# 6        5643       1
# 7        5705       1
# 8        6430       1
# 9        8000       5
# 10       8126       1
# 11       8200       1
# 12       8272       1
# 13       8302       1
# 14       8306       1
# 15       8360       1
# 16       8400       1
# 17       8483       1
# 18       8484       1
# 19       8489       1
# 20       8537       1
# 21       8564       1
# 22       8570       1
# 23       8645       1
# 24       8800       1
# 25       8803       2
# 26       8805       1
# 27       8820       1
# 28       8852       1
# 29       8854       1
# 30       8873       1
# 31       9033       1
# 32       9042       1
# 33       9230       1
# 34       9240       1
# 35       9320       2
# 36       9442       2
# 37       9562       1

# %%
# Merge grouped aby data with density.csv
df = df_count.merge(df_density,on = 'Post Code',how = 'left')
df['gig_per'] = 100*df['Counts']/df['Population']
# Define urban column
df['urban'] = 'unknown'
df.loc[df['Density']<400, 'urban'] = 'rural'
df.loc[(df['Density']>=400) & (df['Density']<1500), 'urban'] = 'urban'
df.loc[df['Density']>1500, 'urban'] = 'urban center'
df.head()
# Out:
#    Post Code  Counts            City               Region  Population    Area  \
# 0       2544       1             NaN  Canton of Solothurn      5616.0  12.200
# 1       3672       1             NaN       Canton of Bern      3317.0  13.000
# 2       4655       1  Rohr Solothurn  Canton of Solothurn      1184.0   8.400
# 3       5000       1           Aarau               Aargau     16836.0   8.600
# 4       5022       1             NaN               Aargau      2371.0   1.311
#
#        Density   gig_per         urban
# 0   460.327869  0.017806         urban
# 1   255.153846  0.030148         rural
# 2   140.952381  0.084459         rural
# 3  1957.674419  0.005940  urban center
# 4  1808.543097  0.042176  urban center

# %%
# Count job number of urban center, urban and rural 
urban_count = df.groupby('urban')['urban'].count()
urban_count
# Out:
# urban
# rural           14
# unknown          1
# urban           17
# urban center     6
# Name: urban, dtype: int64

# %%
import seaborn as sns
sns.set_style("whitegrid")
plt.figure(figsize=(15,8))
ax = sns.boxplot(x="urban", y="gig_per",               
data=df, palette="Set3")

# %%
urban = df[df["urban"]=='urban']['gig_per']
urban_center = df[df["urban"]=='urban center']['gig_per']
rural = df[df["urban"]=='rural']['gig_per']
plt.hist(urban, color = 'c', edgecolor='black',alpha=0.65,bins = 50)
plt.axvline(urban.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(urban.median(), color='b', linestyle='dashed', linewidth=1)

# %%
plt.hist(urban_center, color = 'c', edgecolor='black',alpha=0.65,bins = 50)
plt.axvline(urban_center.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(urban_center.median(), color='b', linestyle='dashed', linewidth=1)

# %%
plt.hist(rural, color = 'c', edgecolor='black',alpha=0.65,bins = 50)
plt.axvline(rural.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(rural.median(), color='b', linestyle='dashed', lingewidth=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/f3/f6xq_wzj2c966dcvz2s9gd1h0000gn/T/ipykernel_23044/1126186032.py in <module>
#       1 plt.hist(rural, color = 'c', edgecolor='black',alpha=0.65,bins = 50)
#       2 plt.axvline(rural.mean(), color='r', linestyle='dashed', linewidth=1)
# ----> 3 plt.axvline(rural.median(), color='b', linestyle='dashed', lingewidth=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2635 @_copy_docstring_and_deprecators(Axes.axvline)
#    2636 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2637     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2638
#    2639
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     788
#     789         trans = self.get_xaxis_transform(which='grid')
# --> 790         l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     791         self.add_line(l)
#     792         self._request_autoscale_view(scalex=scalex, scaley=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     395         # update kwargs before updating data to give the caller a
#     396         # chance to init axes (and hence unit support)
# --> 397         self.update(kwargs)
#     398         self.pickradius = pickradius
#     399         self.ind_offset = 0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in update(self, props)
#    1060                     func = getattr(self, f"set_{k}", None)
#    1061                     if not callable(func):
# -> 1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
#    1064                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'lingewidth'
