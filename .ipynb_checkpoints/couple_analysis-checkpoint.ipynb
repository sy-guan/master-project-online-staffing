# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read data
df = pd.read_csv('coople_data.csv')

# %%
# Hourly salary histogram
pay_per_hour = df["Pay per hour"]

plt.hist(pay_per_hour, color = 'c', edgecolor='black',alpha=0.65)
plt.axvline(pay_per_hour.mean(), color='r', linestyle='dashed', linewidth=1)
print(pay_per_hour.mean())
# Out:
# 28.903313388182358

# %%
df.boxplot(column =['Pay per hour'], grid = False)
# Out:
# <AxesSubplot:>

# %%
# Total salary histogram
pay_per_hour = df["Pay total"]

plt.hist(pay_per_hour, color = 'c', edgecolor='black',alpha=0.65, bins=60)
plt.axvline(pay_per_hour.mean(), color='r', linestyle='dashed', linewidth=1)
print(pay_per_hour.mean())
# Out:
# 2887.979222139111

# %%
df.boxplot(column =['Pay total'], grid = False)
# Out:
# <AxesSubplot:>

# %%
# Industry and frequency
d = {}
for i in df["Industry"]:
    if i not in d.keys():
        d[i] = 1
    else:
        d[i] += 1
d.pop(np.nan)
print(d)
# Out:
# {'Gastronomie / Hotel': 725, 'Promotion / Event': 234, 'Detailhandel / Logistik': 223, 'Luftverkehr': 7, 'Gesundheitswesen': 98, 'Kaufmännische Berufe': 25, 'Handwerk': 4}

# %%
d = {}
for i in df["Post Code"]:
    if i not in d.keys():
        d[i] = 1
    else:
        d[i] += 1
print(d)
len(list(d.keys()))
# Out:
# {2000: 5, 8957: 6, 8803: 1, 8058: 17, 6130: 2, 5503: 1, 1913: 4, 8001: 113, 8302: 16, 4623: 3, 4303: 1, 3053: 2, 8570: 2, 7550: 2, 3552: 4, 8623: 1, 8152: 12, 8008: 13, 3014: 13, 4562: 3, 8044: 10, 8604: 8, 8852: 8, 8125: 3, 8303: 1, 4500: 4, 8424: 3, 8708: 3, 6006: 3, 8032: 5, 3902: 3, 8048: 41, 8005: 16, 8134: 4, 3236: 4, 4601: 2, 3714: 1, 8404: 6, 3076: 4, 8483: 3, 9220: 3, 8606: 3, 4600: 4, 3007: 7, 8400: 12, 8060: 6, 9001: 14, 5210: 7, 8004: 9, 1950: 1, 6005: 16, 6330: 3, 3280: 3, 3098: 6, 7018: 2, 9000: 18, 4624: 1, 3015: 1, 3052: 3, 9244: 2, 8590: 3, 8450: 1, 6331: 1, 8050: 8, 8136: 1, 8047: 4, 3012: 2, 6030: 1, 8153: 1, 8618: 3, 6032: 3, 8304: 31, 5400: 4, 7323: 2, 3602: 2, 3011: 12, 3250: 2, 5033: 3, 8873: 3, 3008: 3, 8808: 5, 3400: 3, 3550: 2, 8610: 4, 3267: 2, 8802: 3, 8002: 15, 8910: 3, 8045: 10, 8953: 3, 8810: 5, 6039: 1, 8640: 9, 9053: 1, 8775: 1, 8600: 22, 4052: 14, 5606: 6, 4143: 1, 6343: 2, 6252: 1, 3110: 2, 3030: 1, 4665: 4, 4051: 12, 8824: 1, 9555: 2, 9405: 4, 1700: 1, 3084: 6, 6405: 3, 5430: 8, 8049: 5, 8180: 5, 7270: 1, 5610: 1, 8037: 1, 3013: 6, 1452: 4, 8310: 2, 8259: 1, 8755: 1, 5630: 4, 3422: 1, 8320: 3, 1920: 3, 5454: 1, 8546: 2, 4657: 2, 8021: 8, 8112: 1, 2540: 2, 8832: 1, 8617: 2, 8952: 14, 6004: 3, 6340: 8, 8942: 4, 8401: 1, 4133: 4, 5012: 2, 8804: 3, 8706: 6, 8345: 2, 8051: 1, 4123: 3, 3073: 3, 3655: 2, 8055: 5, 3600: 3, 4056: 3, 8126: 1, 8700: 2, 5408: 1, 3027: 3, 3604: 12, 3175: 1, 9016: 1, 8645: 6, 8500: 2, 8157: 3, 4058: 6, 3004: 3, 8854: 2, 2800: 2, 4053: 3, 6410: 1, 1003: 3, 5728: 1, 3700: 2, 1022: 1, 5742: 1, 6045: 2, 6300: 6, 7302: 1, 6010: 5, 4153: 3, 8253: 1, 5616: 1, 4127: 2, 5600: 1, 8447: 2, 6402: 1, 6002: 6, 8252: 2, 2555: 1, 3414: 1, 8607: 5, 3063: 3, 5401: 1, 4144: 1, 7083: 1, 4222: 2, 4125: 2, 8046: 1, 8820: 2, 5014: 1, 4313: 2, 7205: 2, 9470: 1, 1110: 2, 8207: 2, 7000: 2, 6020: 7, 1201: 8, 2502: 3, 5603: 1, 8053: 1, 8201: 3, 3123: 1, 8409: 2, 9565: 2, 8052: 1, 6023: 5, 1936: 2, 5057: 3, 6354: 1, 8462: 1, 9015: 37, 8847: 1, 8093: 2, 8003: 1, 6212: 1, 7310: 2, 3018: 2, 5628: 2, 8307: 2, 8038: 2, 4142: 2, 8630: 1, 6390: 2, 3800: 12, 9200: 9, 9515: 2, 1024: 3, 3001: 57, 5722: 1, 4625: 1, 6363: 30, 3074: 2, 3715: 1, 8306: 1, 9542: 1, 5620: 1, 5070: 1, 1209: 1, 1218: 1, 6003: 7, 3048: 1, 1205: 3, 8406: 1, 1204: 1, 1814: 1, 8108: 2, 8472: 1, 1306: 1, 5080: 2, 1348: 1, 4528: 1, 6423: 1, 8064: 2, 8092: 2, 3006: 1, 4932: 1, 3627: 1, 4107: 2, 2504: 2, 8620: 2, 6373: 1, 4102: 1, 5415: 2, 8010: 1, 8716: 1, 3855: 1, 8489: 1, 6043: 1, 8200: 2, 4800: 2, 4702: 1, 1716: 1, 9630: 1, 1214: 1, 9107: 2, 8733: 2, 1006: 11, 8272: 1, 5442: 3, 5032: 5, 4900: 2, 9500: 2, 6047: 1, 3115: 1, 8363: 1, 5044: 1, 8405: 1, 8006: 1, 1206: 1, 6900: 1, 3302: 1, 6048: 1, 8902: 1, 1800: 1, 5444: 1, 3132: 1, 4532: 1, 6035: 5, 9403: 2, 3825: 1, 3072: 2, 3010: 1, 4001: 10, 6592: 1, 5506: 1, 8580: 2, 1630: 2, 8800: 1, 8117: 1, 6210: 1, 1010: 1, 1442: 1, 2034: 1, 2900: 1, 8057: 1, 1227: 1, 1163: 1, 3172: 1, 1207: 1, 4410: 2, 3537: 1, 8853: 1, 3960: 1, 2300: 1, 1470: 1, 5604: 1, 7078: 3, 7077: 2}
# 336

# %%
# Industry category
industry_cat = d.keys()
industry_cat
# Out:
# dict_keys(['Gastronomie / Hotel', 'Promotion / Event', 'Detailhandel / Logistik', 'Luftverkehr', 'Gesundheitswesen', 'Kaufmännische Berufe', 'Handwerk'])

# %%
# Job number by industry
names = list(d.keys())
values = list(d.values())

fig = plt.figure(1, [12, 7])
plt.bar(range(len(d)), values, tick_label=names, edgecolor='black', color = 'c', alpha=0.65)
plt.show()

# %%
# Histogram with industry and salary, return mean
def plot_hist_industry(industry,salary): 
    l = []
    for index, row in df.iterrows():
        if row['Industry'] == industry:
            l.append(row[salary])
            
    mean = sum(l)/len(l)
    plt.hist(l, bins=10, color = 'c', edgecolor='black',alpha=0.65)
    plt.xlabel(salary)
    plt.ylabel('Frequency')
    min_ylim, max_ylim = plt.ylim()
    plt.axvline(mean, color='r', linestyle='dashed', linewidth=1)
    plt.text(mean*1.06, max_ylim*0.9, 'Mean: {:.2f}'.format(mean))
    plt.title(industry)
    plt.show()

    return l

# %%
# Hourly salary VS total salary
def hour_total_hist(industry):
    l1, l2 = [],[]
    for index, row in df.iterrows():
        if row['Industry'] == industry:
            l1.append(row['Pay per hour'])
            l2.append(row['Pay total'])
            
    fig = plt.figure(2, [14, 5])
    plt.subplot(1, 2, 1)
    mean1 = sum(l1)/len(l1)
    plt.hist(l1, bins=30, color = 'c', edgecolor='black',alpha=0.65)
    plt.xlabel('Pay per hour')
    plt.ylabel('Frequency')
    min_ylim, max_ylim = plt.ylim()
    plt.axvline(mean1, color='r', linestyle='dashed', linewidth=1)
    plt.text(mean1*1.06, max_ylim*0.9, 'Mean: {:.2f}'.format(mean1))

    plt.subplot(1, 2, 2)
    mean2 = sum(l2)/len(l2)
    plt.hist(l2, bins=20, color = 'c', edgecolor='black',alpha=0.65)
    plt.xlabel('Pay total')
    plt.ylabel('Frequency')
    min_ylim, max_ylim = plt.ylim()
    plt.axvline(mean2, color='r', linestyle='dashed', linewidth=1)
    plt.text(mean2*1.06, max_ylim*0.9, 'Mean: {:.2f}'.format(mean2))
    
    plt.suptitle(industry)
    plt.show()

# %%
hour_total_hist('Gastronomie / Hotel')

# %%
hour_total_hist('Promotion / Event')

# %%
hour_total_hist('Detailhandel / Logistik')

# %%
hour_total_hist('Luftverkehr')

# %%
hour_total_hist('Kaufmännische Berufe')

# %%
hour_total_hist('Gesundheitswesen')

# %%
df.boxplot(by ='Industry', column =['Pay per hour'], grid = False, figsize = (12,7))
# Out:
# <AxesSubplot:title={'center':'Pay per hour'}, xlabel='Industry'>

# %%
df.boxplot(by ='Industry', column =['Pay total'], grid = False, figsize = (12,7))
# Out:
# <AxesSubplot:title={'center':'Pay total'}, xlabel='Industry'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.boxplot(y = 'Industry', x = 'Pay per hour', data = df)
# Out:
# <AxesSubplot:xlabel='Pay per hour', ylabel='Industry'>

# %%
sns.boxplot(y = 'Industry', x = 'Pay total', data = df)
# Out:
# <AxesSubplot:xlabel='Pay total', ylabel='Industry'>

# %%
df2 = pd.read_csv('post-codes.csv')
merged_df = pd.merge(df, df2, on='Post Code', how='left')

# %%
merged_df.to_csv('data_lat.csv')
